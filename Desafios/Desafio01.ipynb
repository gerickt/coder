# %% [markdown]
# ### Desafío 01 - Elección de Datasets Potenciales
#
# Gerick Toro - Comisión 46270
#
# ---
#
# ### I: Construcción de los dataframes

# %%
import pandas as pd

# %%
# URL de los datasets
url1 = "https://raw.githubusercontent.com/gerickt/coder/bcd8e89af58ea3bc3d5079ccd3c52f19d22a3e4d/Data/AirlinePassengerSatisfaction/airline_passenger_satisfaction.csv"
url1_dic = "https://raw.githubusercontent.com/gerickt/coder/bcd8e89af58ea3bc3d5079ccd3c52f19d22a3e4d/Data/AirlinePassengerSatisfaction/data_dictionary.csv"

url2 = "https://raw.githubusercontent.com/gerickt/coder/bcd8e89af58ea3bc3d5079ccd3c52f19d22a3e4d/Data/MarketingCampaignResults/marketing_data.csv"
url2_dic = "https://raw.githubusercontent.com/gerickt/coder/bcd8e89af58ea3bc3d5079ccd3c52f19d22a3e4d/Data/MarketingCampaignResults/marketing_data_dictionary.csv"

url3 = "https://raw.githubusercontent.com/gerickt/coder/bcd8e89af58ea3bc3d5079ccd3c52f19d22a3e4d/Data/OnlineChessGames/chess_games.csv"

# %%
# Dataframe 01 y diccionario de campos: Airline Passenger Satisfaction
df1 = pd.read_csv(url1, index_col=0)
df1_dic = pd.read_csv(url1_dic, index_col=0)

# Dataframe 02 y diccionario de campos: Marketing Campaing Results
df2 = pd.read_csv(url2, index_col="ID")
df2_dic = pd.read_csv(url2_dic, index_col=0)

# Dataframe 03: Online Chess Games
df3 = pd.read_csv(url3)

# %%
# Limpieza de variables
del url1, url2, url3, url1_dic, url2_dic

# %% [markdown]
# ---
#
# ### II: Exploración de los dataframes

# %%
# Dimension de los dataframes potenciales
for i in range(1, 4):
    dataframe = f"df{i}"
    shape = locals()[dataframe].shape
    print(f"Shape de {dataframe}: {shape}")
# Out:
# Shape de df1: (129880, 23)
# Shape de df2: (2240, 27)
# Shape de df3: (20058, 17)

# %%
# Revision de los dataframes

df1.head()
# df2.head()
# df3.head()
# Out:
#     Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# ID
# 1     Male   48    First-time       Business  Business              821
# 2   Female   35     Returning       Business  Business              821
# 3     Male   41     Returning       Business  Business              853
# 4     Male   50     Returning       Business  Business             1905
# 5   Female   49     Returning       Business  Business             3470
#
#     Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# ID
# 1                 2            5.0                                       3
# 2                26           39.0                                       2
# 3                 0            0.0                                       4
# 4                 0            0.0                                       2
# 5                 0            1.0                                       3
#
#     Ease of Online Booking  ...  On-board Service  Seat Comfort  \
# ...

# %%
# Descripción de las columnas
df1_dic
# df2_dic
# Out:
#                                                                               Description
# Field
# ID                                                            Unique passenger identifier
# Gender                                              Gender of the passenger (Female/Male)
# Age                                                                  Age of the passenger
# Customer Type                             Type of airline customer (First-time/Returning)
# Type of Travel                                  Purpose of the flight (Business/Personal)
# Class                                   Travel class in the airplane for the passenger...
# Flight Distance                                                  Flight distance in miles
# Departure Delay                                         Flight departure delay in minutes
# Arrival Delay                                             Flight arrival delay in minutes
# ...

# %%
# Buscando valores nulos
df1.isnull().sum()
# Out:
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# In-flight Wifi Service                      0
# ...

# %%
# Resumen estadistico de las columnas numericas
df1.describe().round(2)
# Out:
#              Age  Flight Distance  Departure Delay  Arrival Delay  \
# count  129880.00        129880.00        129880.00      129487.00
# mean       39.43          1190.32            14.71          15.09
# std        15.12           997.45            38.07          38.47
# min         7.00            31.00             0.00           0.00
# 25%        27.00           414.00             0.00           0.00
# 50%        40.00           844.00             0.00           0.00
# 75%        51.00          1744.00            12.00          13.00
# max        85.00          4983.00          1592.00        1584.00
#
#        Departure and Arrival Time Convenience  Ease of Online Booking  \
# count                               129880.00               129880.00
# mean                                     3.06                    2.76
# std                                      1.53                    1.40
# min                                      0.00                    0.00
# ...

# %%
# Frecuencia de respuestas negativas o positivas
df1["Satisfaction"].value_counts()
# Out:
# Satisfaction
# Neutral or Dissatisfied    73452
# Satisfied                  56428
# Name: count, dtype: int64

# %%
# Frecuencia de pasajeros hombres y mujeres
df1["Gender"].value_counts()
# Out:
# Gender
# Female    65899
# Male      63981
# Name: count, dtype: int64

# %%
# Frecuencia de la clase del pasajero
df1["Class"].value_counts()
# Out:
# Class
# Business        62160
# Economy         58309
# Economy Plus     9411
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ### III: Conclusiones
#
# Despues de revisar los 3 datasets, por la facilidad de interpretación y la utilidad posible para la construcción de proyecto, he seleccionado el df1.
#
# **Airline Passenger Satisfaction**
